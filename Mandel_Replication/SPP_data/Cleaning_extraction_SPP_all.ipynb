# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
SSP = pd.read_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/SSP_IAM_V2_201811.csv", index_col = ["MODEL","SCENARIO"])

# %%
SSP2 = pd.read_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/SSP_IAM_V2_201811.csv", index_col = ["MODEL"])

# %%
SSP2.index.value_counts()
# Out:
# GCAM4              16597
# IMAGE              15950
# AIM/CGE            14492
# WITCH-GLOBIOM      14195
# REMIND-MAGPIE      11936
# MESSAGE-GLOBIOM    11183
# Name: MODEL, dtype: int64

# %%
SSP.head()
# Out:
#                     REGION                                  VARIABLE  \
# MODEL   SCENARIO
# AIM/CGE SSP1-19   R5.2ASIA                 Agricultural Demand|Crops
#         SSP1-19   R5.2ASIA          Agricultural Demand|Crops|Energy
#         SSP1-19   R5.2ASIA             Agricultural Demand|Livestock
#         SSP1-19   R5.2ASIA      Agricultural Production|Crops|Energy
#         SSP1-19   R5.2ASIA  Agricultural Production|Crops|Non-Energy
#
#                              UNIT       2005       2010       2020       2030  \
# MODEL   SCENARIO
# AIM/CGE SSP1-19   million t DM/yr  1045.1420  1127.8730  1274.2943  1617.3621
#         SSP1-19   million t DM/yr     0.0000     5.2135    27.0726   347.4691
#         SSP1-19   million t DM/yr    85.9985    94.1085   107.8967   118.3935
#         SSP1-19   million t DM/yr     0.0000     0.0000     3.8007    63.0178
#         SSP1-19   million t DM/yr  1329.1994  1421.9173  1570.7293  1669.9784
#
# ...

# %%
WITCHGLOBIOM = SSP.loc["WITCH-GLOBIOM"].loc["SSP5-Baseline"]
WITCHGLOBIOM = WITCHGLOBIOM[WITCHGLOBIOM["REGION"] == "R5.2OECD"]
WITCHGLOBIOM = WITCHGLOBIOM[["VARIABLE", "2005","2010", "2020", "2030", "2040", "2050", "2060", "2070", "2080", "2090", "2100"]] 
WITCHGLOBIOM1 = WITCHGLOBIOM.set_index("VARIABLE")
WITCHGLOBIOMT= WITCHGLOBIOM.set_index("VARIABLE").transpose()
WITCHGLOBIOM1.to_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/WITCHGLOBIOM_1_SSP5.csv")
WITCHGLOBIOMT.to_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/WITCHGLOBIOM_T_SSP5.csv")

# %%
imageSSP5 = SSP.loc["IMAGE"].loc["SSP5-Baseline"]
imageSSP5 = imageSSP5[imageSSP5["REGION"]=="R5.2OECD"]
imageSSP5 = imageSSP5[["VARIABLE", "2005","2010", "2020", "2030", "2040", "2050", "2060", "2070", "2080", "2090", "2100"]] 
imageSSP51 = imageSSP5.set_index("VARIABLE")
imageSSP5T= imageSSP5.set_index("VARIABLE").transpose()
imageSSP51.to_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/IMAGE_1_SSP5.csv")
imageSSP5T.to_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/IMAGE_T_SSP5.csv")

# %%
AIMCGE = SSP.loc["AIM/CGE"].loc["SSP5-Baseline"]
AIMCGE = AIMCGE[AIMCGE["REGION"] == "R5.2OECD"]
AIMCGE = AIMCGE[["VARIABLE", "2005","2010", "2020", "2030", "2040", "2050", "2060", "2070", "2080", "2090", "2100"]] 
AIMCGE1 = AIMCGE.set_index("VARIABLE")
AIMCGET= AIMCGE.set_index("VARIABLE").transpose()
AIMCGE1.to_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/AIMCGE_1_SSP5.csv")
AIMCGET.to_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/AIMCGE_T_SSP5.csv")

# %%
GCAM4 = SSP.loc["GCAM4"].loc["SSP5-Baseline"]
GCAM4 = GCAM4[GCAM4["REGION"] == "R5.2OECD"] 
GCAM4 = GCAM4[["VARIABLE", "2005","2010", "2020", "2030", "2040", "2050", "2060", "2070", "2080", "2090", "2100"]] 
GCAM41 = GCAM4.set_index("VARIABLE")
GCAM4T= GCAM4.set_index("VARIABLE").transpose()
GCAM41.to_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/GCAM4_1_SSP5.csv")
GCAM4T.to_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/GCAM4_T_SSP5.csv")

# %%
REMINDMAGPIE = SSP.loc["REMIND-MAGPIE"].loc["SSP5-Baseline"]
REMINDMAGPIE = REMINDMAGPIE[REMINDMAGPIE["REGION"] == "R5.2OECD"] 
REMINDMAGPIE = REMINDMAGPIE[["VARIABLE", "2005","2010", "2020", "2030", "2040", "2050", "2060", "2070", "2080", "2090", "2100"]] 
REMINDMAGPIE1 = REMINDMAGPIE.set_index("VARIABLE")
REMINDMAGPIET= REMINDMAGPIE.set_index("VARIABLE").transpose()
REMINDMAGPIE1.to_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/REMINDMAGPIE_1_SSP5.csv")
REMINDMAGPIET.to_csv("C:/Users/Carteron Adelin/Documents/3.EDHEC cours/2.M2/2. Semester 2/0.Master_Project/2.Data/3.SSP/1.SPP_IAM_V2_2018_all/REMINDMAGPIE_T_SSP5.csv")

# %%
#Pas de SPP5 dans MESSAGE-GLOBIOM
#MESSAGEGLOBIOM = SSP.loc["MESSAGE-GLOBIOM"].loc["SSP5-Baseline"]
#MESSAGEGLOBIOM = MESSAGEGLOBIOM[MESSAGEGLOBIOM["REGION"] == "R5.2OECD"]
#MESSAGEGLOBIOM = MESSAGEGLOBIOM[["VARIABLE", "2005","2010", "2020", "2030", "2040", "2050", "2060", "2070", "2080", "2090", "2100"]] 
#MESSAGEGLOBIOM1 = MESSAGEGLOBIOM.set_index("VARIABLE")
#MESSAGEGLOBIOMT= MESSAGEGLOBIOM.set_index("VARIABLE").transpose()

# %%
imageSSP5["REGION"].value_counts()
# Out:
# World       123
# R5.2ASIA    113
# R5.2LAM     113
# R5.2MAF     113
# R5.2OECD    113
# R5.2REF     113
# Name: REGION, dtype: int64

# %%
WITCHGLOBIOM = WITCHGLOBIOM[["VARIABLE", "2005","2010", "2020", "2030", "2040", "2050", "2060", "2070", "2080", "2090", "2100"]]

# %%
WITCHGLOBIOM.set_index("VARIABLE").transpose()
# Out:
# VARIABLE  Capacity|Electricity  Capacity|Electricity|Biomass  \
# 2005               2339.151500                     35.210000
# 2010               2599.569086                     48.401837
# 2020               3189.271693                     58.098284
# 2030               4101.407218                     58.000000
# 2040               5405.590585                     68.102386
# 2050               7022.699422                     79.215730
# 2060               8777.231557                     86.345081
# 2070              10902.118205                     86.656593
# 2080              13864.433334                     86.905148
# 2090              17760.988174                     87.120267
# 2100              22439.081947                     87.255354
#
# VARIABLE  Capacity|Electricity|Coal  Capacity|Electricity|Gas  \
# 2005                     698.358000                645.724000
# 2010                     710.775993                744.507274
# ...

# %%
T.columns
# Out:
# Index(['SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
#        'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline', 'SSP5-Baseline',
# ...
